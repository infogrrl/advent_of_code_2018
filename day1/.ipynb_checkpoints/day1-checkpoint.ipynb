# %%
import pandas as pd
import itertools

# %%
ins = pd.read_table("input.txt", header=None)
ins
# Out:
#           0
# 0       -10
# 1        18
# 2         5
# 3         1
# 4         1
# 5       -19
# 6       -13
# 7        -4
# 8        -4
# 9        -5
# 10      -17
# 11       13
# 12       -3
# 13       18
# 14      -17
# 15       14
# 16       11
# 17       14
# 18       16
# 19        6
# 20       -2
# 21       -3
# 22       -3
# 23       -5
# 24       18
# 25       17
# 26       -9
# 27       14
# 28       13
# 29        3
# ...     ...
# 986      27
# 987       6
# 988       4
# 989      20
# 990       8
# 991      -3
# 992      66
# 993    -139
# 994     -21
# 995      11
# 996     -19
# 997      20
# 998     -13
# 999     -31
# 1000      7
# 1001     -2
# 1002      5
# 1003     -2
# 1004      4
# 1005    -16
# 1006      7
# 1007      6
# 1008    -21
# 1009    -10
# 1010    -12
# 1011     25
# 1012     -7
# 1013    -17
# 1014    -13
# 1015  73906
#
# [1016 rows x 1 columns]

# %%
ins.sum(0)
# Out:
# 0    513
# dtype: int64

# %%
test_list_a = [1, -2, 3, 1] # reaches 2 twice
test_list_b = [1, -1] # 0
test_list_c = [3, 3, 4, -2, -4] # 10
test_list_d = [-6, 3, 8, 5, -6] # 5
test_list_e = [7, 7, -2, -7, -4] # 14

# %%
# input_list = test_list_a
input_list = list(ins[0])
input_list
# Out:
# [-10,
#  18,
#  5,
#  1,
#  1,
#  -19,
#  -13,
#  -4,
#  -4,
#  -5,
#  -17,
#  13,
#  -3,
#  18,
#  -17,
#  14,
#  11,
#  14,
#  16,
#  6,
#  -2,
#  -3,
#  -3,
#  -5,
#  18,
#  17,
#  -9,
#  14,
#  13,
#  3,
#  -17,
#  -3,
#  11,
#  -4,
#  -5,
#  3,
#  9,
#  -20,
#  -18,
#  10,
#  1,
#  1,
#  -14,
#  9,
#  -5,
#  20,
#  -6,
#  1,
#  2,
#  2,
#  -13,
#  -11,
#  18,
#  18,
#  1,
#  2,
#  -11,
#  23,
#  2,
#  -7,
#  2,
#  7,
#  -3,
#  6,
#  9,
#  8,
#  13,
#  -8,
#  12,
#  7,
#  4,
#  9,
#  -11,
#  -19,
#  1,
#  13,
#  15,
#  -14,
#  10,
#  19,
#  -6,
#  1,
#  7,
#  -14,
#  3,
#  17,
#  2,
#  2,
#  15,
#  15,
#  18,
#  6,
#  -9,
#  8,
#  15,
#  12,
#  15,
#  5,
#  8,
#  1,
#  6,
#  -13,
#  18,
#  10,
#  10,
#  7,
#  14,
#  4,
#  9,
#  17,
#  10,
#  6,
#  7,
#  9,
#  5,
#  1,
#  1,
#  19,
#  10,
#  18,
#  -5,
#  10,
#  7,
#  -6,
#  -10,
#  17,
#  -12,
#  -15,
#  -17,
#  5,
#  7,
#  -11,
#  18,
#  -12,
#  -12,
#  -3,
#  10,
#  -4,
#  -5,
#  13,
#  10,
#  -1,
#  7,
#  -12,
#  -11,
#  -9,
# ...

# %%
c = 0
seen = []
for n in itertools.cycle(input_list):
    if c not in seen:
        seen.append(c)
        #print(seen)
        c += n
        #print("c = " + str(c))
    else:
        break
print(c)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-50-aa6113590c72> in <module>
#       4     if c not in seen:
#       5         seen.append(c)
# ----> 6         print(seen)
#       7         c += n
#       8         print("c = " + str(c))
#
# KeyboardInterrupt:
